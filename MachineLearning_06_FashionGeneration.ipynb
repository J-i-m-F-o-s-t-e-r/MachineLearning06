# %% [markdown]
# <a href="https://colab.research.google.com/github/J-i-m-F-o-s-t-e-r/MachineLearning06/blob/master/MachineLearning_06_FashionGeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print('GPU device not found')
else:
  print('Got the GPU hot and ready.')
# Out:
# Got the GPU hot and ready.

# %%
# !git clone https://github.com/J-i-m-F-o-s-t-e-r/MachineLearning06.git
# Out:
# Cloning into 'MachineLearning06'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 88 (delta 3), reused 9 (delta 3), pack-reused 75
# Unpacking objects: 100% (88/88), done.

# %%
# !pip3 install scipy==1.1.0
# Out:
# ...
#      |████████████████████████████████| 31.2MB 65.5MB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.3.1
#     Uninstalling scipy-1.3.1:
#       Successfully uninstalled scipy-1.3.1
# ...

# %%
# !python3 ./MachineLearning06/main.py --dataset fashion-mnist --gan_type GAN --epoch 10 --batch_size 1
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From ./MachineLearning06/main.py:79: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From ./MachineLearning06/main.py:79: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2019-10-10 12:45:21.599939: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-10-10 12:45:21.600250: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1cd1100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...
